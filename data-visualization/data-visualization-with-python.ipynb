# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x  = [1,  2, 3]
y1 = [1,  4, 9]
y2 = [10, 5, 0]
plt.plot(x, y1)
plt.plot(x, y2)
plt.title('Test Plot')
plt.xlabel('X - axis')
plt.xlabel('Y - axis')
plt.legend(['y1','y2'])
plt.show()

# %%
sample_data = pd.read_csv('sample_data.csv')
sample_data
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.column_c
# Out:
# 0    10
# 1     8
# 2     6
# 3     4
# 4     2
# Name: column_c, dtype: int64

# %%
type(sample_data.column_c)
# Out:
# pandas.core.series.Series

# %%
sample_data.column_c.iloc[0] # Retrieves a specific value
# Out:
# 10

# %%
sample_data.column_c.iloc[1]
# Out:
# 8

# %%
plt.plot(sample_data.column_a, sample_data.column_b, 'o')
plt.plot(sample_data.column_a, sample_data.column_c, 'r:')
plt.show()

# %%
data = pd.read_csv('countries.csv')
data
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %% [markdown]
# ### Compare the population growth in US and India

# %%
data.country == 'United States'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703    False
# Name: country, Length: 1704, dtype: bool

# %%
us = data[data.country == 'United States']
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
ind = data[data.country == 'India']
ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %% [markdown]
# ### Population Growth - India and US

# %%
plt.plot(ind.year, ind.population/10**6, 'green')
plt.plot(us.year,  us.population/10**6,  'red'  )
plt.title('Population Growth - India and US')
plt.legend(['India','United States'])
plt.xlabel('Year')
plt.ylabel('Population (in millions)')
plt.show()

# %% [markdown]
# ### Percentage Population Growth relative to Population of First Year - India and US

# %%
plt.plot(ind.year, (ind.population/ind.population.iloc[0])*100, 'green')
plt.plot(ind.year, (us.population/us.population.iloc[0])*100,   'red'  )
plt.title('Percentage Population Growth relative to Population of First Year - India and US')
plt.legend(['India','United States'])
plt.xlabel('Year')
plt.ylabel('Percentage Population Growth')
plt.show()
